# %% [markdown]
# ## Convolutional Neural Network

# %% [markdown]
# ### Case 1 : Pre-Trained VGG Model

# %%
import numpy as np
import pprint as pp
import matplotlib.pyplot as plt
import pandas as pd
import os
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD
import cv2
from keras import backend as K
# Out:
# Using Theano backend.
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.

# %%
K.set_image_dim_ordering('th')
# Set the folder path name here, else ignore and make it commented
path= ""

# %%
# Defining the VGG model
def VGG_16(weights_path=None):
    model = Sequential()
    model.add(ZeroPadding2D((1,1),input_shape=(3,224,224)))
    model.add(Convolution2D(64, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(64, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1000, activation='softmax'))

    if weights_path:
        model.load_weights(weights_path)

    return model

# %%
labels = [" ".join(row.split(' ')[1:]) for row in open(os.path.join(path, "labels.txt")).read().strip().split('\n')]
df_labels = pd.DataFrame({"label": labels})
im = cv2.resize(cv2.imread(os.path.join(path, 'cat.jpg')), (224, 224)).astype(np.float32)
im[:,:,0] -= 103.939
im[:,:,1] -= 116.779
im[:,:,2] -= 123.68
im = im.transpose((2,0,1))
im = np.expand_dims(im, axis=0)

# %%
# Test pretrained model
model = VGG_16(os.path.join(path,'vgg16_weights (2).h5')) #https://drive.google.com/file/d/0Bz7KyqmuGsilT0J5dmRCM0ROVHc/view
sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd, loss='categorical_crossentropy')
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:11: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu")`
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu")`
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:17: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu")`
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:19: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu")`
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:21: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu")`
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:25: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:27: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:33: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:35: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:37: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`

# %%
out = model.predict(im)
pred = dict(zip(labels, model.predict_proba(im)[0]))
best_guess = labels[np.argmax(out)]

output = []
guesses = np.array(labels)[np.argsort(out[0])].tolist()
guesses.reverse()
for item in guesses[:10]:
    output.append(item)

output = ", ".join(output)
best_guess = ",".join(output.split(", ")[:10])
plt.imshow(cv2.imread(os.path.join(path,'cat.jpg')))
print "It's a %s" % best_guess
{ "guess": best_guess, "prob": pred }
# Out:
# 1/1 [==============================] - 341s
# It's a Egyptian cat,tabby,tabby cat,lynx,catamount,tiger cat,Siamese cat,Siamese,carton,bucket
# {'guess': 'Egyptian cat,tabby,tabby cat,lynx,catamount,tiger cat,Siamese cat,Siamese,carton,bucket',
#  'prob': {'Afghan hound, Afghan': 3.3911689e-08,
#   'African chameleon, Chamaeleo chamaeleon': 3.2255161e-07,
#   'African crocodile, Nile crocodile, Crocodylus niloticus': 8.9182244e-09,
#   'African elephant, Loxodonta africana': 2.1014108e-09,
#   'African grey, African gray, Psittacus erithacus': 2.2506943e-06,
#   'African hunting dog, hyena dog, Cape hunting dog, Lycaon pictus': 1.0936121e-07,
#   'Airedale, Airedale terrier': 3.8707853e-07,
#   'American Staffordshire terrier, Staffordshire terrier, American pit bull terrier, pit bull terrier': 9.2224263e-06,
#   'American alligator, Alligator mississipiensis': 1.2347697e-08,
#   'American black bear, black bear, Ursus americanus, Euarctos americanus': 2.3995856e-08,
#   'American chameleon, anole, Anolis carolinensis': 3.5025821e-06,
#   'American coot, marsh hen, mud hen, water hen, Fulica americana': 4.8584661e-07,
#   'American egret, great white heron, Egretta albus': 1.2067854e-06,
#   'American lobster, Northern lobster, Maine lobster, Homarus americanus': 5.827419e-07,
#   'Angora, Angora rabbit': 0.00037018623,
#   'Appenzeller': 5.262375e-07,
#   'Arabian camel, dromedary, Camelus dromedarius': 5.6582468e-09,
#   'Arctic fox, white fox, Alopex lagopus': 1.697943e-06,
#   'Australian terrier': 2.2615739e-05,
#   'Band Aid': 1.5938829e-05,
#   'Bedlington terrier': 1.1333511e-06,
#   'Bernese mountain dog': 2.5256642e-07,
#   'Blenheim spaniel': 2.7294828e-07,
#   'Border collie': 1.1299909e-05,
#   'Border terrier': 2.0296817e-07,
#   'Boston bull, Boston terrier': 0.00083841721,
#   'Bouvier des Flandres, Bouviers des Flandres': 1.9831436e-06,
#   'Brabancon griffon': 3.6337218e-07,
#   'Brittany spaniel': 1.572617e-06,
#   'CD player': 3.7640991e-06,
#   'Cardigan, Cardigan Welsh corgi': 5.2585351e-06,
#   'Chesapeake Bay retriever': 2.5774366e-07,
#   'Chihuahua': 0.000208003,
#   'Christmas stocking': 2.5988687e-05,
#   'Crock Pot': 1.9970639e-05,
#   'Dandie Dinmont, Dandie Dinmont terrier': 1.1010726e-07,
#   'Doberman, Doberman pinscher': 1.0611021e-05,
#   'Dungeness crab, Cancer magister': 2.9341223e-07,
#   'Dutch oven': 5.6243908e-07,
#   'Egyptian cat': 0.69911367,
#   'English foxhound': 8.9838528e-07,
#   'English setter': 2.5961609e-07,
#   'English springer, English springer spaniel': 3.8895073e-06,
#   'EntleBucher': 1.7447462e-07,
#   'Eskimo dog, husky': 0.001970635,
#   'European fire salamander, Salamandra salamandra': 3.3262562e-08,
#   'European gallinule, Porphyrio porphyrio': 4.0860877e-07,
#   'French bulldog': 4.1553216e-05,
#   'French horn, horn': 3.6394808e-06,
#   'French loaf': 2.4310256e-07,
#   'German shepherd, German shepherd dog, German police dog, alsatian': 4.3694267e-06,
#   'German short-haired pointer': 7.8394769e-06,
#   'Gila monster, Heloderma suspectum': 7.9418276e-09,
#   'Gordon setter': 2.8168847e-08,
#   'Granny Smith': 9.4399729e-05,
#   'Great Dane': 3.0012463e-05,
#   'Great Pyrenees': 2.3892517e-07,
#   'Greater Swiss Mountain dog': 2.8164405e-07,
#   'Ibizan hound, Ibizan Podenco': 0.0025628251,
#   'Indian cobra, Naja naja': 1.8912401e-07,
#   'Indian elephant, Elephas maximus': 1.5402728e-08,
#   'Irish setter, red setter': 9.740981e-08,
#   'Irish terrier': 3.1553466e-07,
#   'Irish water spaniel': 8.9635314e-08,
#   'Irish wolfhound': 1.8307432e-07,
#   'Italian greyhound': 0.00013701692,
#   'Japanese spaniel': 1.4195886e-06,
#   'Kerry blue terrier': 1.5927053e-07,
#   'Komodo dragon, Komodo lizard, dragon lizard, giant lizard, Varanus komodoensis': 3.3472316e-09,
#   'Labrador retriever': 9.0186791e-07,
#   'Lakeland terrier': 1.3272336e-06,
#   'Leonberg': 7.9087226e-09,
#   'Lhasa, Lhasa apso': 3.6312603e-08,
#   'Loafer': 5.4671062e-07,
#   'Madagascar cat, ring-tailed lemur, Lemur catta': 1.9071452e-06,
#   'Maltese dog, Maltese terrier, Maltese': 2.1652075e-07,
#   'Mexican hairless': 6.1740342e-05,
#   'Model T': 9.2792064e-08,
#   'Newfoundland, Newfoundland dog': 3.7566039e-08,
#   'Norfolk terrier': 7.4448144e-07,
#   'Norwegian elkhound, elkhound': 8.1198541e-06,
#   'Norwich terrier': 1.6161492e-05,
#   'Old English sheepdog, bobtail': 1.2350207e-06,
#   'Pekinese, Pekingese, Peke': 1.5927949e-07,
#   'Pembroke, Pembroke Welsh corgi': 6.9893952e-07,
#   'Persian cat': 0.00014220303,
#   'Petri dish': 4.0510736e-07,
#   'Polaroid camera, Polaroid Land camera': 3.7113057e-06,
#   'Pomeranian': 4.1117542e-07,
#   'Rhodesian ridgeback': 4.6660734e-08,
#   'Rottweiler': 1.2885002e-07,
#   'Saint Bernard, St Bernard': 2.6646862e-07,
#   'Saluki, gazelle hound': 1.3733539e-07,
#   'Samoyed, Samoyede': 2.2348124e-07,
#   'Scotch terrier, Scottish terrier, Scottie': 5.6217101e-05,
#   'Scottish deerhound, deerhound': 1.1333116e-07,
#   'Sealyham terrier, Sealyham': 1.4452107e-06,
#   'Shetland sheepdog, Shetland sheep dog, Shetland': 2.2907589e-07,
#   'Shih-Tzu': 2.6354004e-07,
#   'Siamese cat, Siamese': 0.026330104,
#   'Siberian husky': 0.00093122741,
#   'Staffordshire bullterrier, Staffordshire bull terrier': 6.533935e-07,
#   'Sussex spaniel': 4.3096981e-07,
#   'Tibetan mastiff': 3.5021992e-09,
#   'Tibetan terrier, chrysanthemum dog': 1.1408329e-07,
#   'Walker hound, Walker foxhound': 1.7495248e-07,
#   'Weimaraner': 8.2658931e-05,
#   'Welsh springer spaniel': 5.0458561e-07,
#   'West Highland white terrier': 2.885329e-05,
#   'Windsor tie': 0.00010944912,
#   'Yorkshire terrier': 8.6851475e-07,
#   'abacus': 4.2652446e-05,
#   'abaya': 3.4786208e-06,
#   "academic gown, academic robe, judge's robe": 3.5753449e-06,
#   'accordion, piano accordion, squeeze box': 2.3681569e-07,
#   'acorn': 1.5856474e-05,
#   'acorn squash': 6.3878829e-08,
#   'acoustic guitar': 4.1659752e-07,
#   'admiral': 9.0331912e-07,
#   'affenpinscher, monkey pinscher, monkey dog': 3.7221926e-07,
#   'agama': 1.0707878e-07,
#   'agaric': 2.2375643e-08,
#   'aircraft carrier, carrier, flattop, attack aircraft carrier': 1.3285613e-07,
#   'airliner': 2.3903411e-07,
#   'airship, dirigible': 2.5766258e-07,
#   'albatross, mollymawk': 2.650075e-06,
#   'alligator lizard': 1.7294467e-06,
#   'alp': 1.1477845e-07,
#   'altar': 3.8819885e-06,
#   'ambulance': 1.1636179e-07,
#   'amphibian, amphibious vehicle': 1.4188772e-07,
#   'analog clock': 8.7504704e-05,
#   'anemone fish': 1.8672181e-07,
#   'ant, emmet, pismire': 1.9270081e-07,
#   'apiary, bee house': 4.5528901e-09,
#   'apron': 2.3031311e-05,
#   'armadillo': 2.6601197e-06,
#   'artichoke, globe artichoke': 1.130911e-06,
#   'ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin': 0.00014412895,
#   'assault rifle, assault gun': 1.590427e-07,
#   'axolotl, mud puppy, Ambystoma mexicanum': 6.3882158e-07,
#   'baboon': 3.1263262e-08,
#   'backpack, back pack, knapsack, packsack, rucksack, haversack': 2.2202947e-05,
#   'badger': 3.0466256e-07,
#   'bagel, beigel': 6.0196874e-07,
#   'bakery, bakeshop, bakehouse': 3.8507005e-07,
#   'balance beam, beam': 1.1749357e-06,
#   'bald eagle, American eagle, Haliaeetus leucocephalus': 1.0200305e-07,
#   'balloon': 2.8993704e-06,
#   'ballplayer, baseball player': 9.3616347e-07,
#   'ballpoint, ballpoint pen, ballpen, Biro': 5.9977119e-05,
#   'banana': 4.0213199e-05,
#   'banded gecko': 6.2180033e-07,
#   'banjo': 6.5785025e-07,
#   'bannister, banister, balustrade, balusters, handrail': 3.3607282e-06,
#   'barbell': 8.12902e-06,
#   'barber chair': 1.3850622e-06,
#   'barbershop': 9.5517225e-07,
#   'barn': 1.506717e-07,
#   'barn spider, Araneus cavaticus': 6.5320097e-07,
#   'barometer': 5.3489886e-05,
#   'barracouta, snoek': 1.6729466e-05,
#   'barrel, cask': 1.3281269e-05,
#   'barrow, garden cart, lawn cart, wheelbarrow': 1.2418431e-05,
#   'baseball': 1.7313634e-05,
#   'basenji': 0.0003045724,
#   'basketball': 7.972904e-07,
#   'basset, basset hound': 3.9665031e-07,
#   'bassinet': 1.8297955e-05,
#   'bassoon': 5.0421454e-06,
#   'bath towel': 0.00040120995,
#   'bathing cap, swimming cap': 4.4819903e-06,
#   'bathtub, bathing tub, bath, tub': 0.00047663564,
#   'beach wagon, station wagon, wagon, estate car, beach waggon, station waggon, waggon': 1.2462387e-07,
#   'beacon, lighthouse, beacon light, pharos': 3.4962945e-08,
#   'beagle': 2.9142527e-07,
#   'beaker': 0.00071382726,
#   'bearskin, busby, shako': 3.961798e-06,
#   'beaver': 1.4973265e-08,
#   'bee': 1.2369638e-07,
#   'bee eater': 4.5775104e-07,
#   'beer bottle': 0.00021940455,
#   'beer glass': 8.3264502e-05,
#   'bell cote, bell cot': 6.0015049e-07,
#   'bell pepper': 4.3483674e-06,
#   'bib': 2.5928184e-05,
#   'bicycle-built-for-two, tandem bicycle, tandem': 4.9840725e-08,
#   'bighorn, bighorn sheep, cimarron, Rocky Mountain bighorn, Rocky Mountain sheep, Ovis canadensis': 2.7110392e-08,
#   'bikini, two-piece': 8.706158e-06,
#   'binder, ring-binder': 5.2147301e-05,
#   'binoculars, field glasses, opera glasses': 2.0181895e-07,
#   'birdhouse': 5.822561e-06,
#   'bison': 4.0403743e-09,
#   'bittern': 9.2890383e-07,
#   'black and gold garden spider, Argiope aurantia': 2.756173e-06,
#   'black grouse': 3.8253518e-08,
#   'black stork, Ciconia nigra': 1.0218542e-07,
#   'black swan, Cygnus atratus': 8.868156e-08,
#   'black widow, Latrodectus mactans': 9.8945725e-07,
#   'black-and-tan coonhound': 3.5769819e-08,
#   'black-footed ferret, ferret, Mustela nigripes': 5.7591128e-06,
#   'bloodhound, sleuthhound': 2.8348671e-07,
#   'bluetick': 2.0077616e-07,
#   'boa constrictor, Constrictor constrictor': 1.3493892e-07,
#   'boathouse': 7.1126567e-09,
#   'bobsled, bobsleigh, bob': 4.0889256e-07,
#   'bolete': 4.6567887e-09,
#   'bolo tie, bolo, bola tie, bola': 2.7440951e-06,
#   'bonnet, poke bonnet': 4.1311752e-05,
#   'book jacket, dust cover, dust jacket, dust wrapper': 4.7466733e-06,
#   'bookcase': 4.5687666e-05,
#   'bookshop, bookstore, bookstall': 2.739949e-05,
#   'borzoi, Russian wolfhound': 3.171883e-07,
#   'bottlecap': 3.1701929e-05,
#   'bow': 3.3694814e-05,
#   'bow tie, bow-tie, bowtie': 0.00073410524,
#   'box turtle, box tortoise': 1.3249932e-07,
#   'boxer': 1.7002293e-06,
#   'brain coral': 1.9510018e-08,
#   'brambling, Fringilla montifringilla': 4.8605909e-08,
#   'brass, memorial tablet, plaque': 1.6909314e-06,
#   'brassiere, bra, bandeau': 9.6239935e-05,
#   'breakwater, groin, groyne, mole, bulwark, seawall, jetty': 7.0233618e-08,
#   'breastplate, aegis, egis': 6.9365058e-05,
#   'briard': 1.0844767e-07,
#   'broccoli': 1.9982261e-05,
#   'broom': 0.00020266211,
#   'brown bear, bruin, Ursus arctos': 8.1515124e-09,
#   'bubble': 2.0203946e-05,
#   'bucket, pail': 0.014513724,
#   'buckeye, horse chestnut, conker': 3.9215201e-06,
#   'buckle': 3.1122458e-05,
#   'bulbul': 5.3197728e-05,
#   'bull mastiff': 4.6256025e-07,
#   'bullet train, bullet': 1.4453367e-07,
#   'bulletproof vest': 1.8741714e-06,
#   'bullfrog, Rana catesbeiana': 1.0663925e-07,
#   'burrito': 1.4974365e-06,
#   'bustard': 4.5777509e-07,
#   'butcher shop, meat market': 4.1322332e-06,
#   'butternut squash': 1.5840234e-06,
#   'cab, hack, taxi, taxicab': 6.0054953e-07,
#   'cabbage butterfly': 1.3035974e-06,
#   'cairn, cairn terrier': 2.7386534e-07,
#   'caldron, cauldron': 0.00032480981,
#   'can opener, tin opener': 0.00016226627,
#   'candle, taper, wax light': 0.001238453,
#   'cannon': 4.6400766e-07,
#   'canoe': 4.8881407e-07,
#   'capuchin, ringtail, Cebus capucinus': 3.2704261e-07,
#   'car mirror': 4.3039663e-06,
#   'car wheel': 2.4936328e-06,
#   'carbonara': 1.5447715e-06,
#   'cardigan': 1.1714527e-06,
#   'cardoon': 6.9824796e-07,
#   'carousel, carrousel, merry-go-round, roundabout, whirligig': 1.2336492e-06,
#   "carpenter's kit, tool kit": 6.9607522e-05,
#   'carton': 0.018065894,
#   'cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM': 7.0246921e-07,
#   'cassette': 1.1335905e-05,
#   'cassette player': 2.6652262e-06,
#   'castle': 4.9841128e-07,
#   'catamaran': 8.8122232e-07,
#   'cauliflower': 1.1694023e-06,
#   'cello, violoncello': 1.8424608e-07,
#   'cellular telephone, cellular phone, cellphone, cell, mobile phone': 5.3998894e-05,
#   'centipede': 1.9708095e-06,
#   'chain': 5.4940767e-05,
#   'chain mail, ring mail, mail, chain armor, chain armour, ring armor, ring armour': 6.6263847e-06,
#   'chain saw, chainsaw': 2.9907842e-08,
#   'chainlink fence': 1.2769103e-06,
#   'chambered nautilus, pearly nautilus, nautilus': 7.6159864e-07,
#   'cheeseburger': 3.3612972e-07,
#   'cheetah, chetah, Acinonyx jubatus': 2.5847608e-08,
#   'chest': 1.2516235e-05,
#   'chickadee': 3.7969944e-08,
#   'chiffonier, commode': 9.6252791e-07,
#   'chime, bell, gong': 6.2956533e-06,
#   'chimpanzee, chimp, Pan troglodytes': 4.0462206e-07,
#   'china cabinet, china closet': 3.4704212e-07,
#   'chiton, coat-of-mail shell, sea cradle, polyplacophore': 6.4692709e-09,
#   'chocolate sauce, chocolate syrup': 3.5373378e-05,
#   'chow, chow chow': 1.2919436e-08,
#   'church, church building': 9.4558809e-06,
#   'cicada, cicala': 4.2407868e-07,
#   'cinema, movie theater, movie theatre, movie house, picture palace': 3.7177031e-06,
#   'cleaver, meat cleaver, chopper': 0.00013374264,
#   'cliff dwelling': 6.2168821e-09,
#   'cliff, drop, drop-off': 2.1140149e-08,
#   'cloak': 1.5018766e-05,
#   'clog, geta, patten, sabot': 3.1326908e-07,
#   'clumber, clumber spaniel': 1.8226042e-07,
#   'cock': 2.4235501e-06,
#   'cocker spaniel, English cocker spaniel, cocker': 1.1710159e-06,
#   'cockroach, roach': 4.2087962e-07,
#   'cocktail shaker': 0.00090978737,
#   'coffee mug': 0.00010931289,
#   'coffeepot': 3.4746205e-05,
#   'coho, cohoe, coho salmon, blue jack, silver salmon, Oncorhynchus kisutch': 4.3394419e-05,
#   'coil, spiral, volute, whorl, helix': 2.3797406e-06,
#   'collie': 6.939671e-06,
#   'colobus, colobus monkey': 3.9388926e-08,
#   'combination lock': 2.2916875e-05,
#   'comic book': 1.984135e-06,
#   'common iguana, iguana, Iguana iguana': 2.7503526e-07,
#   'common newt, Triturus vulgaris': 6.7181332e-08,
#   'computer keyboard, keypad': 0.00040888926,
#   'conch': 1.7202349e-06,
#   'confectionery, confectionary, candy store': 3.1747913e-07,
#   'consomme': 2.0762188e-06,
#   'container ship, containership, container vessel': 2.7845491e-07,
#   'convertible': 2.9498369e-07,
#   'coral fungus': 1.0225824e-07,
#   'coral reef': 4.2844519e-08,
#   'corkscrew, bottle screw': 0.00021477978,
#   'corn': 8.7149092e-05,
#   'cornet, horn, trumpet, trump': 1.081592e-05,
#   'coucal': 2.5528113e-08,
#   'cougar, puma, catamount, mountain lion, painter, panther, Felis concolor': 1.6663687e-05,
#   'cowboy boot': 9.1901915e-05,
#   'cowboy hat, ten-gallon hat': 2.0152605e-05,
#   'coyote, prairie wolf, brush wolf, Canis latrans': 1.1542857e-06,
#   'cradle': 1.1623081e-05,
#   'crane': 5.020886e-07,
#   'crash helmet': 2.8317854e-06,
#   'crate': 6.2945823e-05,
#   'crayfish, crawfish, crawdad, crawdaddy': 2.137286e-05,
#   'crib, cot': 3.3715452e-05,
#   'cricket': 1.408861e-06,
#   'croquet ball': 5.252215e-06,
#   'crossword puzzle, crossword': 0.00026041458,
#   'crutch': 3.9440311e-06,
#   'cucumber, cuke': 2.580979e-05,
#   'cuirass': 1.4313277e-05,
#   'cup': 0.0027907079,
#   'curly-coated retriever': 3.9018119e-08,
#   'custard apple': 1.482504e-06,
#   'daisy': 3.1032886e-07,
#   'dalmatian, coach dog, carriage dog': 1.5929772e-05,
#   'dam, dike, dyke': 2.6949282e-08,
#   'damselfly': 2.5430737e-07,
#   'desk': 5.2760865e-06,
#   'desktop computer': 4.5324945e-05,
#   'dhole, Cuon alpinus': 3.508996e-07,
#   'dial telephone, dial phone': 2.3940015e-06,
#   'diamondback, diamondback rattlesnake, Crotalus adamanteus': 1.6463848e-07,
#   'diaper, nappy, napkin': 4.2961296e-06,
#   'digital clock': 2.5087929e-05,
#   'digital watch': 2.2324639e-06,
#   'dingo, warrigal, warragal, Canis dingo': 5.9879017e-06,
#   'dining table, board': 1.7167114e-06,
#   'dishrag, dishcloth': 5.7204477e-07,
#   'dishwasher, dish washer, dishwashing machine': 9.8608965e-05,
#   'disk brake, disc brake': 2.8775247e-07,
#   'dock, dockage, docking facility': 8.1684703e-07,
#   'dogsled, dog sled, dog sleigh': 4.9417815e-07,
#   'dome': 4.4793965e-06,
#   'doormat, welcome mat': 0.00024655828,
#   'dough': 4.5297784e-06,
#   'dowitcher': 2.359902e-08,
#   "dragonfly, darning needle, devil's darning needle, sewing needle, snake feeder, snake doctor, mosquito hawk, skeeter hawk": 6.436133e-07,
#   'drake': 3.9854277e-07,
#   'drilling platform, offshore rig': 4.9361638e-08,
#   'drum, membranophone, tympan': 5.8159571e-06,
#   'drumstick': 0.00011491685,
#   'dugong, Dugong dugon': 1.1608037e-07,
#   'dumbbell': 2.2405444e-05,
#   'dung beetle': 5.5000102e-09,
#   'ear, spike, capitulum': 7.4698277e-05,
#   'earthstar': 5.1840567e-07,
#   'echidna, spiny anteater, anteater': 3.1183998e-08,
#   'eel': 1.6593418e-07,
#   'eft': 2.8727166e-08,
#   'eggnog': 2.90156e-05,
#   'electric fan, blower': 7.8727871e-06,
#   'electric guitar': 2.4978672e-06,
#   'electric locomotive': 1.0222416e-08,
#   'electric ray, crampfish, numbfish, torpedo': 9.7505272e-06,
#   'entertainment center': 2.5002098e-06,
#   'envelope': 2.8926081e-05,
#   'espresso': 8.066474e-06,
#   'espresso maker': 4.8888983e-06,
#   'face powder': 5.9362996e-05,
#   'feather boa, boa': 0.006075942,
#   'fiddler crab': 7.6402475e-09,
#   'fig': 5.1551983e-06,
#   'file, file cabinet, filing cabinet': 2.7049871e-05,
#   'fire engine, fire truck': 1.0933775e-07,
#   'fire screen, fireguard': 3.3717479e-05,
#   'fireboat': 2.8655097e-06,
#   'flagpole, flagstaff': 5.2297655e-05,
#   'flamingo': 2.0993679e-07,
#   'flat-coated retriever': 1.3134914e-07,
#   'flatworm, platyhelminth': 2.4444282e-07,
#   'flute, transverse flute': 3.5046271e-06,
#   'fly': 1.2396487e-06,
#   'folding chair': 1.1576326e-06,
#   'football helmet': 1.2125918e-06,
#   'forklift': 2.2798986e-07,
#   'fountain': 1.6925973e-05,
#   'fountain pen': 0.00025923349,
#   'four-poster': 3.9544261e-06,
#   'fox squirrel, eastern fox squirrel, Sciurus niger': 3.2698695e-06,
#   'freight car': 1.4730819e-07,
#   'frilled lizard, Chlamydosaurus kingi': 7.3709572e-08,
#   'frying pan, frypan, skillet': 0.00016081138,
#   'fur coat': 4.1483349e-06,
#   'gar, garfish, garpike, billfish, Lepisosteus osseus': 2.1292966e-05,
#   'garbage truck, dustcart': 6.375285e-08,
#   'garden spider, Aranea diademata': 3.4587811e-07,
#   'garter snake, grass snake': 9.8861356e-08,
#   'gas pump, gasoline pump, petrol pump, island dispenser': 1.2135009e-06,
#   'gasmask, respirator, gas helmet': 4.4990043e-06,
#   'gazelle': 1.2538558e-06,
#   'geyser': 1.2061572e-06,
#   'giant panda, panda, panda bear, coon bear, Ailuropoda melanoleuca': 8.4964817e-09,
#   'giant schnauzer': 1.5652786e-05,
#   'gibbon, Hylobates lar': 1.6749004e-07,
#   'go-kart': 9.8327329e-09,
#   'goblet': 0.000644646,
#   'golden retriever': 1.1358272e-07,
#   'goldfinch, Carduelis carduelis': 3.0633487e-07,
#   'goldfish, Carassius auratus': 5.293295e-07,
#   'golf ball': 4.5450815e-05,
#   'golfcart, golf cart': 7.0829984e-08,
#   'gondola': 4.2603904e-07,
#   'gong, tam-tam': 1.6836366e-05,
#   'goose': 5.5957997e-07,
#   'gorilla, Gorilla gorilla': 3.2815484e-07,
#   'gown': 1.6713079e-06,
#   'grand piano, grand': 6.1819821e-07,
#   'grasshopper, hopper': 9.7692537e-06,
#   'great grey owl, great gray owl, Strix nebulosa': 2.1557637e-06,
#   'great white shark, white shark, man-eater, man-eating shark, Carcharodon carcharias': 2.1887841e-05,
#   'green lizard, Lacerta viridis': 5.8556047e-06,
#   'green mamba': 9.1555756e-07,
#   'green snake, grass snake': 1.420315e-07,
#   'greenhouse, nursery, glasshouse': 3.9469791e-07,
#   'grey fox, gray fox, Urocyon cinereoargenteus': 9.0510332e-07,
#   'grey whale, gray whale, devilfish, Eschrichtius gibbosus, Eschrichtius robustus': 1.6191173e-07,
#   'grille, radiator grille': 1.2820731e-06,
#   'grocery store, grocery, food market, market': 1.5802649e-06,
#   'groenendael': 1.5851507e-06,
#   'groom, bridegroom': 2.4055601e-07,
#   'ground beetle, carabid beetle': 9.0791417e-08,
#   'guacamole': 2.0161706e-06,
#   'guenon, guenon monkey': 1.2337575e-06,
#   'guillotine': 3.7219422e-06,
#   'guinea pig, Cavia cobaya': 1.2330987e-06,
#   'gyromitra': 2.7992956e-08,
#   'hair slide': 1.2479626e-06,
#   'hair spray': 3.6567668e-05,
#   'half track': 6.1780338e-07,
#   'hammer': 0.00029754933,
#   'hammerhead, hammerhead shark': 1.9035284e-05,
#   'hamper': 0.0017096772,
#   'hamster': 2.5145058e-05,
#   'hand blower, blow dryer, blow drier, hair dryer, hair drier': 6.3778821e-06,
#   'hand-held computer, hand-held microcomputer': 1.646385e-05,
#   'handkerchief, hankie, hanky, hankey': 2.9124356e-05,
#   'hard disc, hard disk, fixed disk': 1.9913963e-05,
#   'hare': 0.00017500798,
#   'harmonica, mouth organ, harp, mouth harp': 2.9555574e-06,
#   'harp': 3.3474262e-07,
#   'hartebeest': 2.5934636e-07,
#   'harvester, reaper': 6.331647e-08,
#   'harvestman, daddy longlegs, Phalangium opilio': 1.0639231e-07,
#   'hatchet': 8.630209e-05,
#   'hay': 3.8661925e-05,
#   'head cabbage': 6.897299e-06,
#   'hen': 4.3815694e-06,
#   'hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa': 2.0961437e-08,
#   'hermit crab': 1.328337e-07,
#   'hip, rose hip, rosehip': 1.8880757e-05,
#   'hippopotamus, hippo, river horse, Hippopotamus amphibius': 1.3482224e-07,
#   'hog, pig, grunter, squealer, Sus scrofa': 2.5645497e-07,
#   'hognose snake, puff adder, sand viper': 1.312399e-06,
#   'holster': 6.8186532e-06,
#   'home theater, home theatre': 2.7776148e-06,
#   'honeycomb': 1.717413e-05,
#   'hook, claw': 0.00030816786,
#   'hoopskirt, crinoline': 9.1990211e-07,
#   'horizontal bar, high bar': 6.1336664e-06,
#   'hornbill': 2.8838558e-08,
#   'horned viper, cerastes, sand viper, horned asp, Cerastes cornutus': 5.6096873e-05,
#   'horse cart, horse-cart': 6.3877587e-07,
#   'hot pot, hotpot': 4.6974279e-07,
#   'hotdog, hot dog, red hot': 1.9115355e-06,
#   'hourglass': 0.00017907876,
#   'house finch, linnet, Carpodacus mexicanus': 1.1605575e-06,
#   'howler monkey, howler': 1.6107083e-07,
#   'hummingbird': 3.8445232e-06,
#   'hyena, hyaena': 7.8618925e-08,
#   'iPod': 0.00010293047,
#   'ibex, Capra ibex': 7.8132524e-07,
#   'ice bear, polar bear, Ursus Maritimus, Thalarctos maritimus': 1.093622e-08,
#   'ice cream, icecream': 1.5657341e-05,
#   'ice lolly, lolly, lollipop, popsicle': 8.4503161e-05,
#   'impala, Aepyceros melampus': 2.605338e-07,
#   'indigo bunting, indigo finch, indigo bird, Passerina cyanea': 2.1427278e-08,
#   'indri, indris, Indri indri, Indri brevicaudatus': 1.1463771e-06,
#   'iron, smoothing iron': 0.00014846532,
#   'isopod': 8.1878319e-08,
#   'jacamar': 2.8487457e-07,
#   "jack-o'-lantern": 3.9128572e-06,
#   'jackfruit, jak, jack': 5.1176778e-07,
#   'jaguar, panther, Panthera onca, Felis onca': 6.9960572e-07,
#   'jay': 1.586434e-05,
#   'jean, blue jean, denim': 1.245008e-05,
#   'jeep, landrover': 5.1296276e-08,
#   'jellyfish': 7.9159825e-09,
#   'jersey, T-shirt, tee shirt': 6.5646458e-07,
#   'jigsaw puzzle': 8.2411898e-06,
#   'jinrikisha, ricksha, rickshaw': 4.657333e-08,
#   'joystick': 6.6681482e-06,
#   'junco, snowbird': 1.2930581e-06,
#   'keeshond': 9.7588057e-08,
#   'kelpie': 0.00061116944,
#   'killer whale, killer, orca, grampus, sea wolf, Orcinus orca': 5.1381392e-07,
#   'kimono': 6.9917992e-06,
#   'king crab, Alaska crab, Alaskan king crab, Alaska king crab, Paralithodes camtschatica': 1.286797e-07,
#   'king penguin, Aptenodytes patagonica': 2.9796872e-06,
#   'king snake, kingsnake': 8.7043685e-07,
#   'kit fox, Vulpes macrotis': 1.8397306e-05,
#   'kite': 1.3042825e-06,
#   'knee pad': 8.2788983e-06,
#   'knot': 1.3094092e-05,
#   'koala, koala bear, kangaroo bear, native bear, Phascolarctos cinereus': 3.8658567e-07,
#   'komondor': 2.991121e-08,
#   'kuvasz': 4.6954349e-07,
#   'lab coat, laboratory coat': 6.5217646e-05,
#   'lacewing, lacewing fly': 2.7998058e-06,
#   'ladle': 0.0002432379,
#   'ladybug, ladybeetle, lady beetle, ladybird, ladybird beetle': 4.2972542e-07,
#   'lakeside, lakeshore': 7.4836201e-08,
#   'lampshade, lamp shade': 6.9368034e-05,
#   'langur': 1.3732701e-07,
#   'laptop, laptop computer': 0.00027201569,
#   'lawn mower, mower': 6.402359e-07,
#   'leaf beetle, chrysomelid': 8.8018757e-09,
#   'leafhopper': 1.2426972e-07,
#   'leatherback turtle, leatherback, leathery turtle, Dermochelys coriacea': 9.3801145e-09,
#   'lemon': 4.5750057e-05,
#   'lens cap, lens cover': 4.8420083e-05,
#   'leopard, Panthera pardus': 6.2611622e-07,
#   'lesser panda, red panda, panda, bear cat, cat bear, Ailurus fulgens': 2.7356499e-08,
#   'letter opener, paper knife, paperknife': 4.1178173e-05,
#   'library': 3.998457e-06,
#   'lifeboat': 3.3586552e-08,
#   'lighter, light, igniter, ignitor': 9.6951291e-05,
#   'limousine, limo': 5.1383307e-07,
#   'limpkin, Aramus pictus': 1.081595e-07,
#   'liner, ocean liner': 3.035729e-07,
#   'lion, king of beasts, Panthera leo': 4.932155e-08,
#   'lionfish': 1.8026377e-08,
#   'lipstick, lip rouge': 0.00041197796,
#   'little blue heron, Egretta caerulea': 1.8120495e-07,
#   'llama': 2.9732662e-06,
#   'loggerhead, loggerhead turtle, Caretta caretta': 4.9982258e-09,
#   'long-horned beetle, longicorn, longicorn beetle': 4.1710916e-07,
#   'lorikeet': 4.8171967e-07,
#   'lotion': 0.0002355793,
#   'loudspeaker, speaker, speaker unit, loudspeaker system, speaker system': 8.7633394e-05,
#   "loupe, jeweler's loupe": 2.8990347e-05,
#   'lumbermill, sawmill': 2.9630023e-08,
#   'lycaenid, lycaenid butterfly': 1.5703121e-06,
#   'lynx, catamount': 0.06429524,
#   'macaque': 7.2301414e-06,
#   'macaw': 2.9937135e-07,
#   'magnetic compass': 4.2909887e-05,
#   'magpie': 9.0767486e-07,
#   'mailbag, postbag': 0.00084411068,
#   'mailbox, letter box': 8.5173933e-06,
#   'maillot': 4.4617653e-05,
#   'maillot, tank suit': 4.417202e-06,
#   'malamute, malemute, Alaskan malamute': 2.5058898e-05,
#   'malinois': 2.4102965e-06,
#   'manhole cover': 1.1122831e-07,
#   'mantis, mantid': 1.321233e-05,
#   'maraca': 8.3386676e-06,
#   'marimba, xylophone': 2.195501e-07,
#   'marmoset': 5.1804142e-07,
#   'marmot': 3.8116279e-09,
#   'mashed potato': 2.1686722e-06,
#   'mask': 0.00020073856,
#   'matchstick': 8.5812499e-06,
#   'maypole': 1.53298e-07,
#   'maze, labyrinth': 4.2075843e-07,
#   'measuring cup': 6.0918828e-05,
#   'meat loaf, meatloaf': 7.127868e-07,
#   'medicine chest, medicine cabinet': 4.4541845e-05,
#   'meerkat, mierkat': 9.9723388e-07,
#   'megalith, megalithic structure': 1.3241001e-07,
#   'menu': 1.7550872e-06,
#   'microphone, mike': 6.5825852e-06,
#   'microwave, microwave oven': 5.3763169e-06,
#   'military uniform': 9.8147884e-06,
#   'milk can': 3.1054413e-05,
#   'miniature pinscher': 3.1560735e-06,
#   'miniature poodle': 4.8865441e-08,
#   'miniature schnauzer': 2.663035e-05,
#   'minibus': 4.4601418e-08,
#   'miniskirt, mini': 5.2057239e-06,
#   'minivan': 2.270302e-07,
#   'mink': 2.057513e-06,
#   'missile': 4.4619905e-05,
#   'mitten': 1.0113858e-06,
#   'mixing bowl': 0.00016585249,
#   'mobile home, manufactured home': 1.1154705e-08,
#   'modem': 2.1412521e-05,
#   'monarch, monarch butterfly, milkweed butterfly, Danaus plexippus': 1.2955149e-07,
#   'monastery': 5.4861806e-07,
#   'mongoose': 1.5218846e-07,
#   'monitor': 0.00020446599,
#   'moped': 8.9118066e-07,
#   'mortar': 5.7308342e-05,
#   'mortarboard': 5.5563214e-05,
#   'mosque': 6.6919552e-06,
#   'mosquito net': 4.815688e-06,
#   'motor scooter, scooter': 4.2434549e-06,
#   'mountain bike, all-terrain bike, off-roader': 1.2930728e-08,
#   'mountain tent': 1.1522769e-07,
#   'mouse, computer mouse': 0.00084088836,
#   'mousetrap': 6.0657323e-05,
#   'moving van': 1.2891898e-07,
#   'mud turtle': 1.032977e-07,
#   'mushroom': 5.0257796e-08,
#   'muzzle': 0.00010803699,
#   'nail': 3.76881e-05,
#   'neck brace': 1.238643e-06,
#   'necklace': 1.7195551e-05,
#   'nematode, nematode worm, roundworm': 2.4431217e-06,
#   'night snake, Hypsiglena torquata': 9.933716e-07,
#   'nipple': 2.3205463e-05,
#   'notebook, notebook computer': 0.00026652569,
#   'obelisk': 1.4164727e-06,
#   'oboe, hautboy, hautbois': 6.9399825e-06,
#   'ocarina, sweet potato': 8.2300048e-06,
#   'odometer, hodometer, mileometer, milometer': 2.2089444e-07,
#   'oil filter': 1.0123909e-05,
#   'orange': 4.7814734e-05,
#   'orangutan, orang, orangutang, Pongo pygmaeus': 7.4089331e-07,
#   'organ, pipe organ': 5.2203478e-07,
#   'oscilloscope, scope, cathode-ray oscilloscope, CRO': 1.3998562e-05,
#   'ostrich, Struthio camelus': 1.2053206e-07,
#   'otter': 1.4863993e-07,
#   'otterhound, otter hound': 1.8473766e-07,
#   'overskirt': 7.4843092e-07,
#   'ox': 1.518469e-07,
#   'oxcart': 4.9376329e-08,
#   'oxygen mask': 6.7951214e-06,
#   'oystercatcher, oyster catcher': 5.3883917e-07,
#   'packet': 8.7659391e-05,
#   'paddle, boat paddle': 1.1052983e-06,
#   'paddlewheel, paddle wheel': 1.8462309e-08,
#   'padlock': 2.3024711e-06,
#   'paintbrush': 0.00011016499,
#   "pajama, pyjama, pj's, jammies": 2.3555256e-05,
#   'palace': 8.9223852e-07,
#   'panpipe, pandean pipe, syrinx': 8.6183445e-06,
#   'paper towel': 0.0020519667,
#   'papillon': 1.1126604e-06,
#   'parachute, chute': 1.6403885e-07,
#   'parallel bars, bars': 4.4157114e-06,
#   'park bench': 1.766185e-07,
#   'parking meter': 3.9145179e-06,
#   'partridge': 6.5248065e-07,
#   'passenger car, coach, carriage': 5.634449e-08,
#   'patas, hussar monkey, Erythrocebus patas': 2.4389723e-07,
#   'patio, terrace': 4.4556461e-07,
#   'pay-phone, pay-station': 9.6236946e-08,
#   'peacock': 6.0505312e-07,
#   'pedestal, plinth, footstall': 2.9290621e-05,
#   'pelican': 2.6145711e-08,
#   'pencil box, pencil case': 2.8356864e-05,
#   'pencil sharpener': 8.164121e-06,
#   'perfume, essence': 0.0001182792,
#   'photocopier': 7.2639932e-06,
#   'pick, plectrum, plectron': 7.6015212e-06,
#   'pickelhaube': 2.0746227e-05,
#   'picket fence, paling': 2.407799e-06,
#   'pickup, pickup truck': 1.7831331e-07,
#   'pier': 1.3131896e-07,
#   'piggy bank, penny bank': 7.4942305e-05,
#   'pill bottle': 1.2444798e-05,
#   'pillow': 0.00013566106,
#   'pineapple, ananas': 0.00019380303,
#   'ping-pong ball': 0.00047018658,
#   'pinwheel': 0.00085459399,
#   'pirate, pirate ship': 9.5424434e-07,
#   'pitcher, ewer': 0.00076967507,
#   'pizza, pizza pie': 2.0831673e-07,
#   "plane, carpenter's plane, woodworking plane": 2.8438391e-08,
#   'planetarium': 1.9149647e-07,
#   'plastic bag': 0.00093906967,
#   'plate': 8.8699071e-06,
#   'plate rack': 6.7146043e-06,
#   'platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus': 1.9784361e-08,
#   'plow, plough': 1.9734095e-07,
#   "plunger, plumber's helper": 0.001405549,
#   'pole': 4.8374141e-06,
#   'polecat, fitch, foulmart, foumart, Mustela putorius': 1.8655975e-06,
#   'police van, police wagon, paddy wagon, patrol wagon, wagon, black Maria': 4.4747633e-08,
#   'pomegranate': 2.2929995e-05,
#   'poncho': 7.809777e-08,
#   'pool table, billiard table, snooker table': 5.4717701e-05,
#   'pop bottle, soda bottle': 0.0001038936,
#   'porcupine, hedgehog': 1.0948393e-07,
#   'pot, flowerpot': 2.9317112e-05,
#   'potpie': 6.4626977e-07,
#   "potter's wheel": 3.5656964e-07,
#   'power drill': 2.104642e-05,
#   'prairie chicken, prairie grouse, prairie fowl': 3.5841153e-06,
#   'prayer rug, prayer mat': 7.0875599e-06,
#   'pretzel': 1.3574129e-06,
#   'printer': 4.6232082e-05,
#   'prison, prison house': 2.2719275e-06,
#   'proboscis monkey, Nasalis larvatus': 8.0023653e-08,
#   'projectile, missile': 0.00022488601,
#   'projector': 3.623631e-07,
#   'promontory, headland, head, foreland': 2.7302756e-08,
#   'ptarmigan': 3.5522199e-08,
#   'puck, hockey puck': 8.9088832e-07,
#   'puffer, pufferfish, blowfish, globefish': 4.5149895e-06,
#   'pug, pug-dog': 1.9695722e-07,
#   'punching bag, punch bag, punching ball, punchball': 0.00070615113,
#   'purse': 0.00042304865,
#   'quail': 2.9920639e-07,
#   'quill, quill pen': 4.7574122e-05,
#   'quilt, comforter, comfort, puff': 8.476185e-05,
#   'racer, race car, racing car': 8.5419991e-08,
#   'racket, racquet': 4.2234783e-06,
#   'radiator': 0.0001817771,
#   'radio telescope, radio reflector': 7.7451446e-08,
#   'radio, wireless': 0.00034379103,
#   'rain barrel': 9.284402e-06,
#   'ram, tup': 9.1561034e-08,
#   'rapeseed': 1.4555451e-07,
#   'recreational vehicle, RV, R.V.': 1.3342459e-07,
#   'red fox, Vulpes vulpes': 4.2488005e-06,
#   'red wine': 0.0016094217,
#   'red wolf, maned wolf, Canis rufus, Canis niger': 4.4295936e-07,
#   'red-backed sandpiper, dunlin, Erolia alpina': 2.7101694e-07,
#   'red-breasted merganser, Mergus serrator': 7.3567008e-08,
#   'redbone': 2.1704359e-07,
#   'redshank, Tringa totanus': 4.3005139e-07,
#   'reel': 3.7990774e-06,
#   'reflex camera': 3.5143364e-06,
#   'refrigerator, icebox': 9.8473167e-05,
#   'remote control, remote': 0.00048222669,
#   'restaurant, eating house, eating place, eatery': 1.4774257e-06,
#   'revolver, six-gun, six-shooter': 2.1999507e-05,
#   'rhinoceros beetle': 5.0522681e-06,
#   'rifle': 2.1979072e-06,
#   'ringlet, ringlet butterfly': 5.6479286e-07,
#   'ringneck snake, ring-necked snake, ring snake': 3.4796875e-07,
#   'robin, American robin, Turdus migratorius': 2.4227597e-06,
#   'rock beauty, Holocanthus tricolor': 3.7980902e-07,
#   'rock crab, Cancer irroratus': 2.6965221e-08,
#   'rock python, rock snake, Python sebae': 1.6748047e-07,
#   'rocking chair, rocker': 1.4330269e-05,
#   'rotisserie': 3.8414245e-07,
#   'rubber eraser, rubber, pencil eraser': 0.00019339241,
#   'ruddy turnstone, Arenaria interpres': 1.8051356e-08,
#   'ruffed grouse, partridge, Bonasa umbellus': 5.7595605e-07,
#   'rugby ball': 1.4792706e-05,
#   'rule, ruler': 0.00018520719,
#   'running shoe': 4.3296554e-06,
#   'safe': 2.1827318e-06,
#   'safety pin': 0.00015782348,
#   'saltshaker, salt shaker': 0.00045354824,
#   'sandal': 5.7118621e-07,
#   'sandbar, sand bar': 1.7424216e-07,
#   'sarong': 4.8493907e-06,
#   'sax, saxophone': 3.3707461e-06,
#   'scabbard': 2.823765e-06,
#   'scale, weighing machine': 0.00043267888,
#   'schipperke': 3.1651205e-05,
#   'school bus': 7.1557409e-08,
#   'schooner': 7.8159919e-06,
#   'scoreboard': 8.8577303e-07,
#   'scorpion': 9.5264318e-07,
#   'screen, CRT screen': 0.00018892095,
#   'screw': 0.00012713987,
#   'screwdriver': 0.00016184666,
#   'scuba diver': 1.659228e-07,
#   'sea anemone, anemone': 6.1343151e-08,
#   'sea cucumber, holothurian': 3.6508723e-08,
#   'sea lion': 1.5291663e-07,
#   'sea slug, nudibranch': 1.2605081e-07,
#   'sea snake': 1.6517815e-08,
#   'sea urchin': 3.4058556e-07,
#   'seashore, coast, seacoast, sea-coast': 1.0161294e-07,
#   'seat belt, seatbelt': 8.7425751e-06,
#   'sewing machine': 1.926504e-06,
#   'shield, buckler': 5.2004474e-05,
#   'shoe shop, shoe-shop, shoe store': 4.4274609e-07,
#   'shoji': 1.8333272e-05,
#   'shopping basket': 4.2705036e-05,
#   'shopping cart': 2.8139609e-06,
#   'shovel': 2.4185847e-05,
#   'shower cap': 3.7675309e-05,
#   'shower curtain': 0.0017829045,
#   'siamang, Hylobates syndactylus, Symphalangus syndactylus': 9.8750684e-07,
#   'sidewinder, horned rattlesnake, Crotalus cerastes': 5.1063336e-07,
#   'silky terrier, Sydney silky': 1.9756419e-06,
#   'ski': 1.7930397e-06,
#   'ski mask': 4.89283e-06,
#   'skunk, polecat, wood pussy': 4.583963e-07,
#   'sleeping bag': 0.00024438501,
#   'slide rule, slipstick': 1.6138389e-05,
#   'sliding door': 1.5723794e-05,
#   'slot, one-armed bandit': 4.4232996e-07,
#   'sloth bear, Melursus ursinus, Ursus ursinus': 4.4152793e-09,
#   'slug': 5.0111062e-06,
#   'snail': 1.2804553e-06,
#   'snorkel': 2.1440555e-07,
#   'snow leopard, ounce, Panthera uncia': 1.8363484e-06,
#   'snowmobile': 4.2157517e-08,
#   'snowplow, snowplough': 2.1519216e-07,
#   'soap dispenser': 9.2250346e-05,
#   'soccer ball': 1.3810361e-05,
#   'sock': 1.6983471e-05,
#   'soft-coated wheaten terrier': 8.7601343e-08,
#   'solar dish, solar collector, solar furnace': 1.0236532e-06,
#   'sombrero': 1.2395122e-05,
#   'sorrel': 8.3098143e-07,
#   'soup bowl': 3.5529236e-05,
#   'space bar': 1.5935949e-06,
#   'space heater': 0.00032401687,
#   'space shuttle': 1.1891335e-06,
#   'spaghetti squash': 2.7360164e-07,
#   'spatula': 3.3371725e-05,
#   'speedboat': 3.9796486e-08,
#   'spider monkey, Ateles geoffroyi': 7.5936306e-08,
#   "spider web, spider's web": 6.5289515e-07,
#   'spindle': 6.172907e-06,
#   'spiny lobster, langouste, rock lobster, crawfish, crayfish, sea crawfish': 3.3418189e-07,
#   'spoonbill': 1.0999067e-07,
#   'sports car, sport car': 4.3951852e-07,
#   'spotlight, spot': 0.00016966449,
#   'spotted salamander, Ambystoma maculatum': 5.6890698e-08,
#   'squirrel monkey, Saimiri sciureus': 1.777052e-07,
#   'stage': 4.2813909e-07,
#   'standard poodle': 1.9653587e-08,
#   'standard schnauzer': 3.8961178e-05,
#   'starfish, sea star': 7.0051442e-07,
#   'steam locomotive': 1.9801718e-07,
#   'steel arch bridge': 5.0759104e-09,
#   'steel drum': 1.1535848e-06,
#   'stethoscope': 0.00026177012,
#   'stingray': 1.3725892e-07,
#   'stinkhorn, carrion fungus': 4.3728072e-08,
#   'stole': 4.1399526e-06,
#   'stone wall': 8.3624869e-08,
#   'stopwatch, stop watch': 4.9584291e-06,
#   'stove': 1.822329e-06,
#   'strainer': 4.4118198e-05,
#   'strawberry': 5.4919707e-05,
#   'street sign': 3.1843857e-07,
#   'streetcar, tram, tramcar, trolley, trolley car': 8.3258385e-07,
#   'stretcher': 4.1875987e-06,
#   'studio couch, day bed': 4.8305519e-05,
#   'stupa, tope': 1.4775032e-06,
#   'sturgeon': 2.0746809e-06,
#   'submarine, pigboat, sub, U-boat': 4.0664287e-07,
#   'suit, suit of clothes': 1.2597102e-05,
#   'sulphur butterfly, sulfur butterfly': 2.9272465e-07,
#   'sulphur-crested cockatoo, Kakatoe galerita, Cacatua galerita': 2.0946382e-07,
#   'sundial': 9.1368875e-06,
#   'sunglass': 6.1695764e-06,
#   'sunglasses, dark glasses, shades': 1.8004774e-05,
#   'sunscreen, sunblock, sun blocker': 0.00015794513,
#   'suspension bridge': 9.8554381e-08,
#   'swab, swob, mop': 0.00010825688,
#   'sweatshirt': 0.0003160444,
#   'swimming trunks, bathing trunks': 2.3126579e-06,
#   'swing': 2.4867957e-06,
#   'switch, electric switch, electrical switch': 2.7694088e-05,
#   'syringe': 0.00058747997,
#   'tabby, tabby cat': 0.071780309,
#   'table lamp': 0.00013916587,
#   'tailed frog, bell toad, ribbed toad, tailed toad, Ascaphus trui': 2.9759043e-08,
#   'tank, army tank, armored combat vehicle, armoured combat vehicle': 9.6805721e-08,
#   'tape player': 1.8516938e-06,
#   'tarantula': 7.559219e-09,
#   'teapot': 9.9752633e-06,
#   'teddy, teddy bear': 4.0962672e-07,
#   'television, television system': 4.0042862e-05,
#   'tench, Tinca tinca': 1.1039989e-07,
#   'tennis ball': 0.001490769,
#   'terrapin': 1.2429318e-07,
#   'thatch, thatched roof': 6.5078375e-08,
#   'theater curtain, theatre curtain': 3.7129305e-06,
#   'thimble': 0.00023047296,
#   'three-toed sloth, ai, Bradypus tridactylus': 1.0704203e-07,
#   'thresher, thrasher, threshing machine': 1.7226078e-07,
#   'throne': 3.4408226e-06,
#   'thunder snake, worm snake, Carphophis amoenus': 8.9805121e-07,
#   'tick': 9.1383517e-06,
#   'tiger beetle': 1.8647187e-08,
#   'tiger cat': 0.039036293,
#   'tiger shark, Galeocerdo cuvieri': 2.1809103e-05,
#   'tiger, Panthera tigris': 9.2190191e-07,
#   'tile roof': 1.7147733e-05,
#   'timber wolf, grey wolf, gray wolf, Canis lupus': 3.6837585e-06,
#   'titi, titi monkey': 8.9923469e-07,
#   'toaster': 2.0182174e-06,
#   'tobacco shop, tobacconist shop, tobacconist': 8.0856989e-06,
#   'toilet seat': 0.0001329097,
#   'toilet tissue, toilet paper, bathroom tissue': 0.00026551977,
#   'torch': 4.1332401e-05,
#   'totem pole': 3.2016194e-06,
#   'toucan': 3.9367953e-07,
#   'tow truck, tow car, wrecker': 6.9312051e-08,
#   'toy poodle': 2.3241361e-07,
#   'toy terrier': 2.8420323e-05,
#   'toyshop': 3.3321763e-07,
#   'tractor': 1.6186216e-07,
#   'traffic light, traffic signal, stoplight': 5.2007222e-06,
#   'trailer truck, tractor trailer, trucking rig, rig, articulated lorry, semi': 2.5586428e-07,
#   'tray': 1.7348657e-05,
#   'tree frog, tree-frog': 2.747291e-07,
#   'trench coat': 6.3811672e-06,
#   'triceratops': 1.4997712e-05,
#   'tricycle, trike, velocipede': 4.3550259e-07,
#   'trifle': 7.3217125e-06,
#   'trilobite': 1.6478693e-07,
#   'trimaran': 4.7805133e-06,
#   'tripod': 3.9241854e-07,
#   'triumphal arch': 6.4119951e-07,
#   'trolleybus, trolley coach, trackless trolley': 7.3818605e-08,
#   'trombone': 4.6603323e-06,
#   'tub, vat': 0.0035598748,
#   'turnstile': 2.0082032e-06,
#   'tusker': 4.0563428e-09,
#   'typewriter keyboard': 1.7179758e-06,
#   'umbrella': 7.2206567e-05,
#   'unicycle, monocycle': 5.4313477e-07,
#   'upright, upright piano': 1.5631737e-07,
#   'vacuum, vacuum cleaner': 3.9712308e-05,
#   'valley, vale': 4.0191935e-08,
#   'vase': 0.0014704714,
#   'vault': 8.3019489e-07,
#   'velvet': 6.6603599e-05,
#   'vending machine': 4.6886094e-06,
#   'vestment': 2.4887838e-06,
#   'viaduct': 3.7369176e-07,
#   'vine snake': 5.1541219e-06,
#   'violin, fiddle': 5.7637908e-07,
#   'vizsla, Hungarian pointer': 5.8775277e-07,
#   'volcano': 1.2806775e-08,
#   'volleyball': 1.2997913e-06,
#   'vulture': 1.4102326e-07,
#   'waffle iron': 3.0396648e-06,
#   'walking stick, walkingstick, stick insect': 6.971019e-06,
#   'wall clock': 0.00010205915,
#   'wallaby, brush kangaroo': 3.6114114e-05,
#   'wallet, billfold, notecase, pocketbook': 7.4157411e-05,
#   'wardrobe, closet, press': 1.6896716e-05,
#   'warplane, military plane': 5.0601807e-06,
#   'warthog': 1.3534083e-08,
#   'washbasin, handbasin, washbowl, lavabo, wash-hand basin': 0.00048456097,
#   'washer, automatic washer, washing machine': 0.00084700959,
#   'water bottle': 0.00030583501,
#   'water buffalo, water ox, Asiatic buffalo, Bubalus bubalis': 2.6165103e-09,
#   'water jug': 7.8594909e-05,
#   'water ouzel, dipper': 5.3090531e-07,
#   'water snake': 8.4844537e-08,
#   'water tower': 3.6515252e-07,
#   'weasel': 4.9863215e-06,
#   'web site, website, internet site, site': 1.4032044e-05,
#   'weevil': 1.2554572e-07,
#   'whippet': 1.9472202e-05,
#   'whiptail, whiptail lizard': 1.2683606e-07,
#   'whiskey jug': 2.1364656e-06,
#   'whistle': 4.6984251e-06,
#   'white stork, Ciconia ciconia': 8.6021096e-08,
#   'white wolf, Arctic wolf, Canis lupus tundrarum': 6.0155407e-06,
#   'wig': 4.1357598e-05,
#   'wild boar, boar, Sus scrofa': 7.5421134e-08,
#   'window screen': 0.0005260153,
#   'window shade': 0.000126646,
#   'wine bottle': 0.00014810062,
#   'wing': 2.1294884e-06,
#   'wire-haired fox terrier': 5.1422253e-06,
#   'wok': 0.00015191898,
#   'wolf spider, hunting spider': 6.8835749e-07,
#   'wombat': 2.2788226e-05,
#   'wood rabbit, cottontail, cottontail rabbit': 7.9008692e-05,
#   'wooden spoon': 0.00011523005,
#   'wool, woolen, woollen': 2.0383304e-06,
#   'worm fence, snake fence, snake-rail fence, Virginia fence': 5.9803313e-07,
#   'wreck': 1.0946492e-07,
#   'yawl': 1.3082048e-05,
#   "yellow lady's slipper, yellow lady-slipper, Cypripedium calceolus, Cypripedium parviflorum": 6.5035971e-07,
#   'yurt': 8.7650012e-09,
#   'zebra': 2.8252344e-07,
#   'zucchini, courgette': 1.0952675e-05}}

# %%
plt.imshow(cv2.imread(os.path.join(path, "cat.jpg")))

# %%
# Another command to show the output :
#from IPython.display import Image
#Image = (filename=path)

# %% [markdown]
# ### Case 2 : Training Model on MNIST

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix
import time
from datetime import timedelta
import math
import pandas as pd

# %%
import gzip
import sys
import pickle
path= "/MNIST_data/data/"

# %%
# For direct load from Keras :
# from keras.datasetsasets import mnist
# (X_train, y_train), (X_test, y_test) = mnist.load_data

# %%
f = gzip.open(os.path.join(path, "mnist.pkl.gz"), 'rb')
if sys.version_info < (3,):
    data = pickle.load(f)
else:
    data = pickle.load(f, encoding='bytes')
f.close()
(x_train, y_train), (x_test, y_test) = data

# %%
X_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
X_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

X_train/=255
X_test/=255


y_train = pd.get_dummies(y_train,columns=[0])
y_train = np.array(y_train, dtype='float32')

y_test = pd.get_dummies(y_test,columns=[0])
y_test = np.array(y_test, dtype='float32')

# %%
def next_batch(num, data, labels):
    '''
    Return a total of `num` random samples and labels. 
    '''
    idx = np.arange(0 , len(data))
    np.random.shuffle(idx)
    idx = idx[:num]
    data_shuffle = [data[ i] for i in idx]
    labels_shuffle = [labels[ i] for i in idx]

    return np.asarray(data_shuffle), np.asarray(labels_shuffle)

# %%
sess = tf.InteractiveSession()

# %%
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev = 0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides = [1, 1, 1, 1], padding = 'SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides = [1, 2, 2, 1], padding = 'SAME')

# %%
x = tf.placeholder("float", shape = [None, 784])
y_ = tf.placeholder("float", shape = [None, 10])

#Make image a 4D tensor
x = tf.reshape(x, [-1, 28, 28, 1])


W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])

h_conv1 = tf.nn.relu(conv2d(x, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)


W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

W_fcl = weight_variable([7 * 7 * 64, 1024])
b_fcl = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2, [-1, 7 * 7 * 64])
h_fcl = tf.nn.relu(tf.matmul(h_pool2_flat, W_fcl) + b_fcl)

keep_prob = tf.placeholder("float")
h_fc1_drop = tf.nn.dropout(h_fcl, keep_prob)

W_fc2 = weight_variable([1024, 10])
b_fc2 = bias_variable([10])

y_conv = tf.nn.softmax(tf.matmul(h_fc1_drop, W_fc2) + b_fc2)

# %%
cross_entropy = -tf.reduce_sum(y_*tf.log(y_conv))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
sess.run(tf.initialize_all_variables())
for i in range(1000):
    batch = next_batch(50,X_train,y_train)
    if i % 100 == 0:
        train_accuracy = accuracy.eval(feed_dict = {x:batch[0], y_: batch[1], keep_prob: 1.0})
        print("step %d, training accuracy %g" % (i, train_accuracy))
    train_step.run(feed_dict = {x: batch[0], y_: batch[1], keep_prob: 0.5})

print("test accuracy %g" % accuracy.eval(feed_dict = {x: X_test, y_: y_test, keep_prob: 1.0}))
# Out:
# WARNING:tensorflow:From <ipython-input-4-a8cb9c4ce1b8>:58: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# step 0, training accuracy 0.1
# step 100, training accuracy 0.78
# step 200, training accuracy 0.86
# step 300, training accuracy 0.9
# step 400, training accuracy 0.96
# step 500, training accuracy 0.94
# step 600, training accuracy 0.94
# step 700, training accuracy 0.96
# step 800, training accuracy 0.98
# step 900, training accuracy 0.98
# test accuracy 0.9655
